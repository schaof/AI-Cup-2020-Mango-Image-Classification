# %%
# !git clone https://github.com/jiangsutx/SRN-Deblur.git

# %%
import os
import shutil
os.chdir("/content/SRN-Deblur/checkpoints")

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !wget http://www.xtao.website/shared_url/srndeblur_models.zip
# !unzip srndeblur_models.zip

# %%
shutil.copy("/content/drive/My Drive/segment_data/10455.jpg", "/content/SRN-Deblur/testing_set")

# %%
os.chdir("/content/SRN-Deblur")

# %%
# !pip uninstall scipy
# !pip install scipy==1.0.0

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.14.0

# %%
# !python run_model.py --gpu=0 --input_path=./testing_set --output_path=./testing_res

# %%
from google.colab.patches import cv2_imshow
import cv2
im=cv2.imread('/content/SRN-Deblur/testing_res/10455.jpg')
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F47825B4550>

# %%
im=cv2.imread('/content/SRN-Deblur/testing_set/10455.jpg')
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0x7F47825B44E0>

# %%
shutil.rmtree("/content/SRN-Deblur/testing_set/.ipynb_checkpoints")
